# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris=pd.read_csv('Iris.csv')

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.shape
# Out:
# (150, 6)

# %%
iris.size
# Out:
# 900

# %%
iris.info
# Out:
# <bound method DataFrame.info of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris.drop('Id',axis=1, inplace=True)

# %%
iris.tail()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica

# %%
sns.countplot('Species', data=iris)
plt.title('Iris Count')
plt.show()

# %%
fig=sns.jointplot(x='SepalLengthCm',y='SepalWidthCm',data=iris)

# %%
fig1=sns.jointplot(x='SepalLengthCm',y='SepalWidthCm', data=iris,kind='hex')

# %%
fig2=sns.jointplot(x='SepalLengthCm',y='SepalWidthCm',kind='reg',data=iris)

# %%
fig3=sns.jointplot(x='SepalLengthCm',y='SepalWidthCm',data=iris,kind='kde',color='r',space=0)

# %%
g=(sns.jointplot(x='SepalWidthCm',y='SepalLengthCm',data=iris,color='g').plot_joint(sns.kdeplot,zorder=0,n_levels=6))

# %%
figure=sns.boxplot(x='Species',y='PetalLengthCm',data=iris)

# %%
iris.boxplot(by='Species',figsize=(14,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E3E348A788>,
# ...
#       dtype=object)

# %%
fig=sns.stripplot(x='Species',y='SepalLengthCm',data=iris,edgecolor='gray',size=8,palette='winter')

# %%
fig=sns.boxplot('Species','SepalLengthCm',data=iris)
fig=sns.stripplot('Species','SepalLengthCm',data=iris)

# %%
figure=sns.violinplot('Species','SepalLengthCm',data=iris)

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.violinplot(x='Species',y='PetalLengthCm',data=iris)
plt.subplot(2,2,2)
sns.violinplot(x='Species',y='PetalLengthCm',data=iris)
plt.subplot(2,2,3)
sns.violinplot(x='Species',y='PetalLengthCm',data=iris)
plt.subplot(2,2,4)
sns.violinplot(x='Species',y='PetalLengthCm',data=iris)
plt.show()

# %%
sns.pairplot(data=iris,kind='scatter')

# %%
sns.pairplot(iris,hue='Species')

# %%
fig=sns.heatmap(iris.corr(),annot=True,cmap='cubehelix')

# %%
sns.set(style="darkgrid")
fig=sns.swarmplot(x='PetalLengthCm',y='Species',data=iris)

# %%
sns.set(style='darkgrid')
sns.boxplot('Species','PetalLengthCm',data=iris)
sns.swarmplot('Species','PetalLengthCm',data=iris)

# %%
sns.set(style='whitegrid')
sns.violinplot('Species','PetalLengthCm',data=iris)
sns.swarmplot('Species','PetalLengthCm',data=iris)

# %%
fig=sns.lmplot(x='PetalLengthCm',y='PetalWidthCm',data=iris)
